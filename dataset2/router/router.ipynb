# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "/scratch/rohank__iitp/qwen2_5_7b_instruct"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
def generate(prompt:str):
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    input_length = inputs['input_ids'].shape[1]
    # Generate text
    outputs = model.generate(
        **inputs,
        max_new_tokens=100,
        do_sample=True,
        top_p=0.9,
        temperature=0.7
    )

    # Decode and print response
    generated_tokens = outputs[0][input_length:]
    response = tokenizer.decode(generated_tokens, skip_special_tokens=True)
    return response.strip()

generate("What is the capital of France?")
# Out:
# 'The capital of France is Paris. \n\nParis is not only the capital but also the largest city in France, located in the northern central part of the country. It is known for its rich history, culture, art, architecture, and fashion. Some famous landmarks in Paris include the Eiffel Tower, Louvre Museum, Notre-Dame Cathedral, and Champs-Élysées. Paris has been a significant center of political power, finance, education, and tourism in Europe and around the world'

# %% [markdown]
# #### Persuassion expert (Gemini)

# %%
def sentiment_expert(text_input: str) -> str:

   prompt = f"""
You are an AI trained to act solely as a **sentiment expert**. Your job is to analyze the **emotional tone** of the input text and classify it into one of the following three categories:

- **Positive** – The text expresses happiness, satisfaction, excitement, appreciation, or any other positive emotion.
- **Negative** – The text expresses disappointment, frustration, anger, sadness, criticism, or other negative feelings.
- **Neutral** – The text is emotionally balanced, factual, or shows no strong emotional content.

Your response must only contain:

1. **Sentiment:** One of the three labels – `Positive`, `Negative`, or `Neutral`
2. **Explanation:** A concise reason that supports the label, based only on emotional tone, word choice, or sentiment-laden phrases.

You must not:
- Provide summaries
- Offer personal opinions
- Evaluate content quality or logic
- Infer intent beyond emotional expression

Stick strictly to **sentiment analysis**.

### Few-Shot Examples:

1. **Text:** "Absolutely love this app – it's made my life so much easier!"
   **Sentiment:** Positive
   **Explanation:** The phrase "absolutely love" strongly conveys enthusiasm and satisfaction.

2. **Text:** "I'm really disappointed with the service. It was slow and rude."
   **Sentiment:** Negative
   **Explanation:** Words like "disappointed", "slow", and "rude" clearly express dissatisfaction.

3. **Text:** "The package arrived on Tuesday as scheduled."
   **Sentiment:** Neutral
   **Explanation:** This sentence is factual with no emotional language.

4. **Text:** "Not sure how I feel about this – it's kind of a mixed bag."
   **Sentiment:** Neutral
   **Explanation:** Ambiguous phrasing and lack of strong emotion suggest a neutral sentiment.

5. **Text:** "This is the worst experience I've had in months."
   **Sentiment:** Negative
   **Explanation:** The phrase "worst experience" indicates strong dissatisfaction.

Now analyze the following text:

**Text:** "{text_input}"
"""


   return generate(prompt)

# %% [markdown]
# #### Persuassion Expert

# %%
def persuassion_expert(text_input: str) -> str:

   prompt = f"""
You are an AI trained to act solely as a **sentiment expert**. Your job is to analyze the **emotional tone** of the input text and classify it into one of the following three categories:

- **Positive** – The text expresses happiness, satisfaction, excitement, appreciation, or any other positive emotion.
- **Negative** – The text expresses disappointment, frustration, anger, sadness, criticism, or other negative feelings.
- **Neutral** – The text is emotionally balanced, factual, or shows no strong emotional content.

Your response must only contain:

1. **Sentiment:** One of the three labels – `Positive`, `Negative`, or `Neutral`
2. **Explanation:** A concise reason that supports the label, based only on emotional tone, word choice, or sentiment-laden phrases.

You must not:
- Provide summaries
- Offer personal opinions
- Evaluate content quality or logic
- Infer intent beyond emotional expression

Stick strictly to **sentiment analysis**.

### Few-Shot Examples:

1. **Text:** "Absolutely love this app – it's made my life so much easier!"
   **Sentiment:** Positive
   **Explanation:** The phrase "absolutely love" strongly conveys enthusiasm and satisfaction.

2. **Text:** "I'm really disappointed with the service. It was slow and rude."
   **Sentiment:** Negative
   **Explanation:** Words like "disappointed", "slow", and "rude" clearly express dissatisfaction.

3. **Text:** "The package arrived on Tuesday as scheduled."
   **Sentiment:** Neutral
   **Explanation:** This sentence is factual with no emotional language.

4. **Text:** "Not sure how I feel about this – it's kind of a mixed bag."
   **Sentiment:** Neutral
   **Explanation:** Ambiguous phrasing and lack of strong emotion suggest a neutral sentiment.

5. **Text:** "This is the worst experience I've had in months."
   **Sentiment:** Negative
   **Explanation:** The phrase "worst experience" indicates strong dissatisfaction.

Now analyze the following text:

**Text:** "{text_input}"
"""


   return generate(prompt)

# %% [markdown]
# #### Keyterm Expert

# %%
def keyterms_expert(text_input: str) -> str:

   prompt = f"""
You are a **Keyterm Expert**. Your job is to extract the most important **key terms or phrases** from the input text. These terms should:

- Reflect the **core concepts**, **entities**, **topics**, or **important actions** in the text.
- Be **noun phrases**, **domain-specific vocabulary**, or **verb-based actions** relevant to the subject.

You must **not**:
- Summarize the text
- Explain or describe the text
- Output full sentences

Your response must include only a list of **key terms or phrases**, separated by commas.

### Few-Shot Examples:

1. **Text:** "Artificial intelligence is transforming industries like healthcare, finance, and education by automating tasks and providing data-driven insights."
   **Key Terms:** Artificial intelligence, healthcare, finance, education, automating tasks, data-driven insights

2. **Text:** "The Amazon rainforest, often referred to as the lungs of the Earth, is being threatened by illegal logging and wildfires."
   **Key Terms:** Amazon rainforest, lungs of the Earth, illegal logging, wildfires

3. **Text:** "Quantum computing uses principles of superposition and entanglement to perform complex calculations much faster than classical computers."
   **Key Terms:** Quantum computing, superposition, entanglement, complex calculations, classical computers

Now extract the key terms from the following text:

**Text:** "{text_input}"
"""

   return generate(prompt)

# %% [markdown]
# #### Intern Expert

# %%
def intent_expert(text_input: str) -> str:

   prompt = f"""
You are an **Intent Expert**. Your task is to analyze the user’s input and identify the **underlying intent** – what the person is trying to do, ask, or achieve with the message.

Intent should be classified in the form of **short, action-oriented phrases** such as:
- "ask a question"
- "make a complaint"
- "request help"
- "give feedback"
- "express gratitude"
- "seek information"
- "report an issue"
- "make a purchase inquiry"

You must provide:

1. **Intent:** A concise label summarizing the user's goal  
2. **Explanation:** A short justification based solely on the user’s wording or phrasing

You must **not**:
- Provide summaries
- Infer sentiment unless directly related to intent
- Rewrite or rephrase the input

Focus only on what the user is trying to achieve.

### Few-Shot Examples:

1. **Text:** "Can you help me reset my password?"  
   **Intent:** request help  
   **Explanation:** The user is directly asking for assistance with resetting their password.

2. **Text:** "This app keeps crashing every time I open it."  
   **Intent:** report an issue  
   **Explanation:** The user is describing a recurring problem with the app.

3. **Text:** "Is there a student discount available for this software?"  
   **Intent:** ask a question  
   **Explanation:** The user is seeking information about discounts.

4. **Text:** "Thanks so much for the quick response!"  
   **Intent:** express gratitude  
   **Explanation:** The user is showing appreciation using thankful language.

5. **Text:** "I’m interested in subscribing to your premium plan."  
   **Intent:** make a purchase inquiry  
   **Explanation:** The user is expressing interest in a paid product or service.

Now identify the intent for the following text:

**Text:** "{text_input}"
"""

   return generate(prompt)

# %%
import json
import re

def convert_structured_to_jsonl(text_block: str, i: int) -> str:
    # dialogue_match = re.search(r"<dialogue>\s*(.*?)\s*</dialogue>", text_block, re.DOTALL)
    # reasoning_match = re.search(r"<reasoning>\s*(.*?)\s*</reasoning>", text_block, re.DOTALL)
    # answer_match = re.search(r"answer\s*(.*?)\s*</answer>", text_block, re.DOTALL)

    # if not (dialogue_match and reasoning_match and answer_match):
    #     raise ValueError("Could not find all required tags in the text.")
    # dialogue = dialogue_match.group(1).strip()
    # reasoning = reasoning_match.group(1).strip()
    # answer = answer_match.group(1).strip()

    data = {
        "id_json":i,

        "answer": text_block.strip()
    }

    res=json.dumps(data)
    with open("/home/rohank__iitp/Work/niladri/dataset2/router/router_response.jsonl", "a") as f:
        f.write(res + "\n")
    return res

# %%
import pandas as pd

# Load CSV
def csv_load(i:int):
    file_path = '/home/rohank__iitp/Work/niladri/dataset2/conversation.csv'
    df = pd.read_csv(file_path)

    conv_id = i
    df = df[df['conversation_id'] == conv_id]

    # Sort by turn number to ensure correct sequence
    df.sort_values(by="turn_no", inplace=True)

    # Prepare conversation history
    history = []
    result = []

    # Iterate through each row except the last one
    for i in range(len(df)):
        row = df.iloc[i]
        speaker = row['speaker']
        utterance = row['utterance']

        # Add current cumulative history to result before appending new utterance
        # result.append(" ".join(history))

        # Add current utterance with speaker label to history
        result.append(f"{speaker}: {utterance}")

    # Add the last utterance in the specified format
    # last_utterance = df.iloc[-1]['utterance']
    # result.append(f"current utterance: {last_utterance}")
    return result

# %% [markdown]
# ### Selecting expert

# %%
# ---------- Router Function ----------
def route_experts(sentence: str) -> list:
    prompt = f"""
You are a well-trained expert selector.
Your job is to analyze the input sentence and determine which of the following expert modules are required.

You MUST choose from the following list:
1 Intent Expert
2 Keyterm Expert
3 Persuasion Expert
4 Sentiment Expert

You may select 1, 2, 3, or all 4 — but only those that are clearly needed based on the text.

Always respond in **this below exact format**:
Input: [original sentence]
Selected Experts: [Expert1, Expert2, etc]
Reason: [one sentence explaining why those experts were selected]

Below is few shot examples to help you understand the format and reasoning:

Example #1

Input: Can someone please help me reset my password?
Selected Experts: [Intent Expert, Keyterm Expert]
Reason: The speaker is making a request (intent) and referring to a specific issue (keyterm).

Example #2
Input: This app is a complete disaster. It crashes every time I try to open it.
Selected Experts: [Intent Expert, Sentiment Expert, Keyterm Expert]
Reason: This is a complaint (intent), expresses negative emotion (sentiment), and includes technical keywords (keyterms).

Example #3
Input: Reset password link not working again.
Selected Experts: [Keyterm Expert]
Reason: Technical/factual content, no emotion or intent expressed.

Example #4
Input: I love how smooth the new interface feels – you guys nailed it!
Selected Experts: [Sentiment Expert, Persuasion Expert]
Reason: Positive emotional tone and praise as persuasion.

### Now process the following:
Input: {sentence}
"""
    try:

        response = generate(prompt)

        # response = model.generate_content(prompt).text.strip()
        selected_experts = []

        # Try regex to match the experts list
        match = re.search(r"Selected Experts:\s*\[(.*?)\]", response)
        if match:
            items = match.group(1).split(',')
            selected_experts = [item.strip().strip('"\'').lower() for item in items if item.strip()]

        return selected_experts
    except Exception as e:
        print("Error routing experts:", e)
        return []
    prompt = f"""
You are a well-trained expert selector.
Your job is to analyze a given input sentence and decide which expert modules should be activated, based on what the speaker is expressing or trying to do.

Available experts:
- Intent Expert: For purpose, request, question, or user goal
- Keyterm Expert: For extracting topic-specific or important terms
- Persuasion Expert: For emotional, persuasive, or rhetorical language
- Sentiment Expert: For emotional tone (positive, negative, or neutral)

Select ONLY the necessary experts based on content. Return 1, 2, 3, or 4 depending on relevance. Do NOT include experts unnecessarily.

### Output Format
Input: [sentence]
Selected Experts: [Expert1, Expert2, ...]
Reason: [Short explanation]

### Examples

Input: Can someone please help me reset my password?
Selected Experts: [Intent Expert, Keyterm Expert]
Reason: Request for help (intent), contains topic terms ("reset password")

Input: This app is a complete disaster. It crashes every time I try to open it.
Selected Experts: [Intent Expert, Sentiment Expert, Keyterm Expert]
Reason: Complaint (intent), frustration (sentiment), key terms mentioned

Input: Reset password link not working again.
Selected Experts: [Keyterm Expert]
Reason: Technical/factual content only

Input: {sentence}
"""

    # Generate response

    response = generate(prompt)

    # Extract list from "Selected Experts:"
    selected_experts = []
    for line in response.splitlines():
        if line.startswith("Selected Experts:"):
            try:
                raw = line.split(":", 1)[1].strip()
                expert_list = eval(raw)  # turns '[Intent Expert, Keyterm Expert]' into list
                selected_experts = [e.lower() for e in expert_list]
            except:
                pass
            break

    return selected_experts






# ---------- Synthesis Function ----------
def generate_combined_analysis(dialogue, intent=None, key=None, persu=None, senti=None):
    prompt = """You are a trained virtual agent.

Your job is to respond to user dialogue in a way that sounds like a helpful, respectful, and professional human agent.  
You will be given internal expert insights that help guide your understanding, but your final output must be a clean, agent-style reply only.

The expert insights may include:
- Intent: What the user is trying to do or ask for  
- Keyterms: Important phrases the user mentioned  
- Sentiment: The emotional tone of the message  
- Persuasion: How the user is expressing or reinforcing their view  

**Important Instructions – You must follow these strictly:**
- Your final response must always sound like a real human agent: calm, clear, empathetic, and helpful.
- Do not include or repeat the input dialogue or any expert outputs in your reply.
- Use only the expert insights given — never guess or make up missing ones.
- Do not describe, explain, or mention the experts or their findings in your response.
- Output a **single, polished agent-style reply only** — no labels, bullet points, or formatting.

Your tone should:
- Acknowledge and validate the user's message  
- Offer clarity, support, or next steps when needed  
- Be persuasive when appropriate, but always respectful  
- Remain professional and human-like, no matter the sentiment

–––– Few-shot Examples ––––

Example 1  
Dialogue: "Why does this feature never work? It’s so frustrating."  
Intent: Wants the issue fixed  
Keyterms: "feature never work", "frustrating"  

Agent Reply: I’m sorry that feature isn’t working as expected—let’s get this sorted for you as quickly as possible.

––––

Example 2  
Dialogue: "The latest update is fantastic. Everything runs smoother now."  
Sentiment: Positive  

Agent Reply: That’s wonderful to hear—thanks for the kind words! We're glad the update made a difference.

––––

Example 3  
Dialogue: "Do you even test this before releasing? It's full of bugs."  
Sentiment: Negative  
Keyterms: "test", "bugs"  
Persuasion: Accusatory tone  

Agent Reply: I completely understand how frustrating that must be. I’ll make sure your feedback reaches our team so we can resolve these issues.

––––

Example 4  
Dialogue: "Can you guys add an option to export in PDF format?"  
Intent: Request for a new feature  

Agent Reply: That’s a great suggestion—PDF export could be really useful. I’ll share this with our team for consideration.

––––

Example 5  
Dialogue: "You say it's for our benefit, but it just feels like more red tape."  
Intent: Questioning the purpose  
Sentiment: Skeptical  
Persuasion: Contrasts stated benefit with added burden  

Agent Reply: I hear your concern, and you’re right—it shouldn’t feel like added work. We’ll do what we can to make the process genuinely helpful.

––––

Example 6  
Dialogue: "Honestly, this is the most useful app I’ve ever used."  
Keyterms: "most useful", "ever used"  
Sentiment: Very positive  

Agent Reply: That’s amazing to hear—thank you! We're thrilled the app has been so helpful for you.

––––

Example 7  
Dialogue: "It’s annoying how I have to log in every single time."  
Intent: Frustration with repetitive process  
Keyterms: "log in", "every time"  

Agent Reply: That does sound inconvenient—I'll check whether there’s a setting or update that can simplify your login experience.

––––

Now, based on the input below, respond exactly as a trained agent would.

**Do not repeat or reference the dialogue or the expert fields in your reply.  
Just return the final agent-style response. Nothing else.**

Dialogue: {dialogue}  
Intent: {intent_output}  
Keyterms: {keyterms_output}  
Sentiment: {sentiment_output}  
Persuasion: {persuasion_output}  

Agent Reply:"""

    return generate(prompt)





# ---------- Main Selector Function ----------
def process_input_with_selector_model(sentence: str) -> str:
    selected_experts = route_experts(sentence)
    print(f"Selected Experts: {selected_experts}")

    # Initialize variables
    intent = keyterms = sentiment = persuasion = None

    # Call only selected experts
    if "intent expert" in selected_experts:
        intent = intent_expert(sentence)
    if "keyterm expert" in selected_experts:
        keyterms = keyterms_expert(sentence)
    if "sentiment expert" in selected_experts:
        sentiment = sentiment_expert(sentence)
    if "persuasion expert" in selected_experts:
        persuasion = persuassion_expert(sentence)

    # Combine everything
    return generate_combined_analysis(
        dialogue=sentence,
        intent=intent,
        key=keyterms,
        persu=persuasion,
        senti=sentiment
    )

# %%
result=list()
for i in range(5,21):
    res = csv_load(i)
    # res.pop(0)
    result.extend(res)  # Use extend to flatten the list
    
len(result)
# Out:
# 209

# %%
i=46
for sentence in result:
    final_output = process_input_with_selector_model(sentence)
    res = convert_structured_to_jsonl(final_output,i)
    i+=1
    print(sentence)
# Out:
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Hi, I'm looking for motor insurance for my 2022 Hyundai Kona Electric. Can you help?
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: Absolutely! The Hyundai Kona Electric is a fantastic car. Given it's an EV, are you particularly concerned about battery coverage or charging-related issues?
# Selected Experts: ['keyterm expert', 'sentiment expert']
# User: Yes, battery coverage is a big concern. I've heard those repairs can be super expensive.
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: I understand. With Tata AIG, we understand the nuances of EVs. Our policy is designed to address modern vehicle risks, it ensures claims are processed quickly and effectively.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Okay, good. What kind of coverage options do you offer for the battery specifically?
# Selected Experts: ['keyterm expert', 'sentiment expert']
# Agent: We offer a comprehensive plan that includes coverage for accidental damage, theft, and also covers the battery against manufacturing defects and certain types of damage. It's a complete package, offering extensive financial protection.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: That sounds reassuring. And what about roadside assistance? Does that cover EVs?
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: Yes, our Roadside Assistance covers EVs. It ensures help is available at any time if you experience vehicle breakdowns, requiring towing services, or emergency repairs while on the road.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: What would the annual premium be for a comprehensive policy like that?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: For a 2022 Hyundai Kona Electric with comprehensive coverage, including battery protection and roadside assistance, the annual premium would be around $1200. Since you're a daily commuter, we can also include Online Policy Management suits your tech-savvy lifestyle
# Selected Experts: ['intent expert', 'keyterm expert']
# User: That's within my budget. Can you send me a detailed quote with all the inclusions?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: Of course! I'll email you a detailed policy brochure and a personalized quote outlining all the benefits and coverage options. This is our most popular plan!
# Selected Experts: ['intent expert', 'keyterm expert']
# User: I need insurance for my 2018 Honda CBR250R. What are my options?
# Selected Experts: ['intent expert', 'keyterm expert']
# Agent: Okay! First, are you primarily concerned with just meeting the minimum legal requirements, or are you looking for more comprehensive protection?
# Selected Experts: ['keyterm expert', 'sentiment expert']
# User: Well, I'm a student, so budget is definitely a concern. But I also don't want to be completely exposed if something happens.
# Selected Experts: ['intent expert', 'persuasion expert']
# Agent: Given your situation as a student, Bajaj Allianz offers prompt claims settlement, so you can focus on recovery, not paperwork.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Okay, what's the difference in price between the minimum and a more comprehensive option?
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: For a 2018 Honda CBR250R, a third-party liability policy, which is the minimum, would be around $300 per year. A comprehensive policy, covering damage to your bike as well, would be about $500.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Hmm, $200 is a decent jump. What does the comprehensive policy actually cover on my bike?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: It covers accidental damage, theft, fire, and natural disasters. And with IFFCO Tokio, you’re choosing a provider known for its customer-first approach and streamlined claims resolution. Their policy ensures clarity and speed during stressful times like accidents or thefts.
# Selected Experts: ['intent expert', 'keyterm expert', 'sentiment expert']
# User: Okay, that does sound better than just liability. Do you offer any discounts for students?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: Yes, because you are a student and drive occasionally, we can offer you a discount on the comprehensive policy. It's a popular choice amongst students because it's affordable and offers complete peace of mind for daily drivers
# Selected Experts: ['intent expert', 'keyterm expert']
# User: I'm looking for insurance for my 2020 Maruti Suzuki Baleno. Can you help me with that?
# Selected Experts: ['intent expert', 'keyterm expert']
# Agent: Certainly! The Maruti Suzuki Baleno is a great car. Given that you likely use it for family commutes, what are your primary concerns?
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Safety for my family is my top priority. I want to make sure everyone is covered in case of an accident.
# Selected Experts: ['intent expert', 'keyterm expert', 'sentiment expert']
# Agent: I understand completely. Accidents are unpredictable, but the financial stress doesn’t have to be. HDFC ERGO policy is crafted to meet specific vehicle protection needs by providing clear, understandable coverage terms
# Selected Experts: ['intent expert', 'keyterm expert']
# User: What kind of personal accident cover do you offer for passengers?
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: Our Personal Accident Cover provides additional financial support in case of serious injury or death resulting from a road accident, covering medical expenses, disability, or loss of income for the insured driver and eligible passengers.
# Selected Experts: ['sentiment expert', 'keyterm expert']
# User: That's good to know. I also worry about the car getting damaged, especially with kids around!
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: Then you'll definitely want comprehensive coverage. It covers damages to your vehicle due to accidents, theft, natural disasters, fire, and vandalism, offering extensive financial protection beyond just third-party coverage.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: What's the claim process like? I don't want a lot of hassle if I need to make a claim.
# Selected Experts: ['persuasion expert', 'keyterm expert']
# Agent: We pride ourselves on our streamlined claim process and customer support. Our claims process is designed to be simple and efficient.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Okay, that's reassuring. How much would a comprehensive policy with personal accident cover cost for my Baleno?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: For a 2020 Maruti Suzuki Baleno with comprehensive coverage and personal accident cover, the annual premium would be approximately $950. Since you are a daily commuter and drive your family, we can offer you Cashless Repair Network that allows policyholders to have their vehicle repairs handled directly by approved service centers without paying upfront
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Hi, I'm interested in getting insurance for my bike, a 2022 Royal Enfield Interceptor 650.
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: Great choice! The Interceptor 650 is a fantastic bike. Since you're a professional and likely value your leisure time, how important is a hassle-free claim process to you?
# Selected Experts: ['intent expert', 'keyterm expert', 'sentiment expert']
# User: A hassle-free claim process is definitely important. I don't want to spend hours on paperwork if something happens.
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: I understand. With IFFCO Tokio, you’re choosing a provider known for its customer-first approach and streamlined claims resolution. Their policy ensures clarity and speed during stressful times like accidents or thefts.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Okay, that sounds promising. What kind of coverage options do you offer?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: We offer both comprehensive and third-party liability coverage. Given that you value a hassle-free experience, I highly recommend the comprehensive coverage. It will cover you for a variety of risks including collisions, theft, and incidental damages.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: What's the approximate cost difference between the two?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: For your bike, the third-party liability might be around $300 annually, while the comprehensive policy would be approximately $650. Since you're a value-seeker, consider this: the extra $350 could save you thousands in case of an accident or theft.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: That's a fair point. What add-ons would you recommend for the comprehensive policy?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: Since you don't drive daily, Roadside Assistance is a great add-on. This ensures that help is available at any time if you experience vehicle breakdowns, requiring towing services, tire changes, fuel delivery, or emergency repairs while on the road.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Okay, roadside assistance sounds useful. How much would that add to the premium?
# Selected Experts: ['intent expert', 'sentiment expert', 'persuasion expert']
# Agent: Roadside assistance would add approximately $50 to the annual premium. It's a small price to pay for the peace of mind knowing you won't be stranded. Accidents are unpredictable, but the financial stress doesn’t have to be. Bajaj Allianz offers prompt claims settlement, so you can focus on recovery, not paperwork.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Alright, I'm interested. Can you send me a quote with the comprehensive coverage and roadside assistance?
# Selected Experts: ['intent expert', 'sentiment expert', 'persuasion expert']
# Agent: Absolutely! I'll email you a detailed quote right away. I think you will find that for the price, the peace of mind is well worth it.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Hi, I'm looking to get insurance for my new bike. It's a 2024 Royal Enfield Himalayan.
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: Congratulations on your new Royal Enfield Himalayan! It's a fantastic bike. As a professional, do you primarily use your bike for leisure or commuting?
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Mostly leisure, weekend rides. I want something reliable, but I'm also on a budget.
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: For weekend rides, you’ll want to ensure your bike is protected from accidents and unforeseen circumstances. With IFFCO Tokio, you’re choosing a provider known for its customer-first approach and streamlined claims resolution. Their policy ensures clarity and speed during stressful times like accidents or thefts.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Okay, good to know. What kind of coverage options do you have for the Himalayan?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: We offer both third-party liability and comprehensive coverage. Given your occasional usage and budget considerations, a comprehensive policy is recommended. It covers damage to your bike, as well as third-party liabilities.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: What add-ons are worth considering?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: Since you often embark on weekend trips, consider Roadside Assistance. This service ensures that help is available at any time if you experience vehicle breakdowns, requiring towing services, tire changes, fuel delivery, or emergency repairs while on the road.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: That sounds useful. How much would the comprehensive policy with roadside assistance cost?
# Selected Experts: ['intent expert', 'keyterm expert', 'sentiment expert']
# Agent: For your 2024 Royal Enfield Himalayan, the comprehensive policy with roadside assistance would be approximately $1200 annually. This plan is affordable and offers complete peace of mind for daily drivers
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Okay, I'm interested. What's the next step?
# Selected Experts: ['intent expert', 'keyterm expert', 'sentiment expert', 'persuasion expert']
# Agent: Great! I can email you a detailed quote with the policy terms and conditions. We can also discuss payment options. Accidents are unpredictable, but the financial stress doesn’t have to be. Bajaj Allianz offers prompt claims settlement, so you can focus on recovery, not paperwork.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Hi, I'm interested in getting motor insurance for my bike. It's a 2022 Yamaha MT-07.
# Selected Experts: ['intent expert', 'persuasion expert', 'keyterm expert']
# Agent: Great choice! The Yamaha MT-07 is a fantastic bike.  Being a professional, your time is valuable. We offer policies with streamlined claims to minimize any disruption to your busy schedule.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: That's good to know. What kind of coverage options do you have?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: We offer both third-party liability and comprehensive coverage. Since the bike is relatively new, I'd strongly recommend comprehensive coverage to protect against theft, accidents, and other damages.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: What's the difference in price between the two?
# Selected Experts: ['keyterm expert', 'sentiment expert']
# Agent: For your Yamaha MT-07, third-party liability would be around $400 per year, while comprehensive coverage would be about $950. Accidents are unpredictable, but the financial stress doesn’t have to be.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Okay, that's a significant jump. What does the comprehensive policy actually cover?
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: Comprehensive coverage includes damage to your bike from accidents (even if it's your fault), theft, fire, vandalism, and natural disasters. It also covers third-party liability if you cause damage to someone else's property or injure them.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: What about roadside assistance?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: Roadside assistance is an optional add-on. However, IFFCO Tokio is known for its customer-first approach and streamlined claims resolution. Their policy ensures clarity and speed during stressful times.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Okay, I think I'd like to go with the comprehensive coverage. Can you give me a quote with roadside assistance?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: Certainly! With roadside assistance added, the annual premium would be $1100. It's one of our most popular plans—most of our clients go for it because it’s affordable and offers complete peace of mind.
# Selected Experts: ['intent expert', 'sentiment expert']
# User: That sounds reasonable. Let's proceed with that.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: I'm looking to get insurance for my bike. It's a 2022 Royal Enfield Interceptor 650.
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: Okay, a 2022 Royal Enfield Interceptor 650. Nice bike! As a professional, you probably value reliability and efficiency. I would recommend Bajaj Allianz for your bike.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: What makes Bajaj Allianz a good choice?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: Bajaj Allianz offers extensive vehicle protection while ensuring that claims are settled quickly. Additional benefits enhance the overall service, making it a dependable choice for minimizing the financial impact of unforeseen events.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: What kind of coverage options are available?
# Selected Experts: ['intent expert', 'persuasion expert', 'keyterm expert']
# Agent: We offer both third-party liability and comprehensive coverage. Given that you are value-seeker and your bike is fairly recent, I would strongly recommend the comprehensive coverage.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: What does the comprehensive policy cover?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: Comprehensive coverage provides all-round protection by including both own-damage and third-party liabilities. It covers damages to your vehicle due to accidents, theft, natural disasters, fire, and vandalism, offering extensive financial protection beyond just third-party coverage.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: That sounds good. What about the claim process?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: Our claim process is designed to be smooth and efficient. We also have a cashless repair network. This feature allows policyholders to have their vehicle repairs handled directly by approved service centers without paying upfront, as costs are settled directly between the insurer and the network garage.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: And what would be the cost of the comprehensive policy?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: For a 2022 Royal Enfield Interceptor 650, the comprehensive policy would be around $950 per year. With Bajaj Allianz, you’re choosing a provider known for its customer-first approach and streamlined claims resolution
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Okay, that seems reasonable. Can you send me a quote?
# Selected Experts: ['intent expert', 'keyterm expert', 'sentiment expert']
# Agent: Absolutely! I'll email you a detailed quote right away. Accidents are unpredictable, but the financial stress doesn’t have to be. We offer prompt claims settlement, so you can focus on recovery, not paperwork.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Hi, I'm interested in getting a motor insurance quote for my 2022 Royal Enfield Classic 350.
# Selected Experts: ['persuasion expert', 'keyterm expert']
# Agent: Certainly! The Royal Enfield Classic 350 is a great bike. As a professional, you probably value both reliability and affordability, correct?
# Selected Experts: ['keyterm expert']
# User: Yes, exactly. I don't use it for daily commuting, mostly weekend rides.
# Selected Experts: ['intent expert', 'keyterm expert', 'sentiment expert']
# Agent: Given your occasional usage, a comprehensive plan might be overkill. However, accidents can still happen. Imagine a minor collision on a weekend ride leading to costly repairs. Our standard plan offers sufficient protection without breaking the bank.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: What does the standard plan cover?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: It covers third-party liability, accidental damage to your bike, and theft. Plus, with IFFCO Tokio, you’re choosing a provider known for its customer-first approach and streamlined claims resolution.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Okay, and how much would that cost?
# Selected Experts: ['intent expert', 'keyterm expert', 'sentiment expert']
# Agent: For your 2022 Royal Enfield Classic 350, the standard plan would be approximately $850 annually. It’s a dependable choice for minimizing the financial impact of unforeseen events.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Are there any discounts available?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: Yes, we offer a digital purchase discount if you buy the policy online. Given you are a professional and most likely tech-savvy, this may be of interest to you.
# Selected Experts: ['sentiment expert', 'keyterm expert']
# User: That sounds good. I'm happy to purchase online.
# Selected Experts: ['intent expert', 'persuasion expert']
# Agent: Excellent! This is one of our popular plans—most of our clients go for it because it’s affordable and offers complete peace of mind for daily drivers
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Okay, let's proceed with the online purchase then.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: I'm looking to insure my bike. It's a 2022 Yamaha MT-07.
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: Okay, a 2022 Yamaha MT-07. Great bike! Do you use it primarily for commuting, or leisure riding?
# Selected Experts: ['keyterm expert']
# User: Mostly for commuting to work daily.
# Selected Experts: ['intent expert', 'persuasion expert']
# Agent: Given that you're using your MT-07 for daily commuting, especially with city traffic, a comprehensive plan is highly recommended. Think about the peace of mind knowing you're covered in case of an accident or theft.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: What does the comprehensive plan cover exactly?
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: It covers damages to your bike from accidents, theft, vandalism, and natural disasters. It also includes third-party liability, protecting you if you cause damage to another person or their property.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Okay, that sounds good. How about roadside assistance?
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: Roadside assistance is included in our comprehensive plan. We offer services like towing, jump-starts, and fuel delivery if you ever find yourself stranded.
# Selected Experts: ['keyterm expert']
# User: What company is this through?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: We offer this coverage through Bajaj Allianz, known for reliability and efficient claims settlement. With Bajaj Allianz, you’re choosing a provider known for its customer-first approach and streamlined claims resolution.
# Selected Experts: ['keyterm expert']
# User: And the cost?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: For a 2022 Yamaha MT-07 with comprehensive coverage and roadside assistance, the annual premium would be approximately $1100. Since you're a daily commuter, you might also benefit from our telematics-based monitoring for premium discounts.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Telematics? Tell me more.
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: It's a small device that tracks your driving habits. Safe driving can earn you discounts on future premiums, so it pays to be responsible!
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Okay, that sounds interesting. Send me the details and I will review it.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Hi, I'm looking for car insurance for my 2018 Tesla Model 3.
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: A 2018 Tesla Model 3, excellent choice! Given that it's a premium electric vehicle, are you looking for comprehensive coverage with all the bells and whistles?
# Selected Experts: ['intent expert', 'sentiment expert']
# User: Yes, I want the best protection possible. Money isn't really an issue, but I need to know my car is fully covered.
# Selected Experts: ['sentiment expert', 'persuasion expert']
# Agent: I understand completely. Peace of mind is priceless, especially with a high-value vehicle. Accidents are unpredictable, but the financial stress doesn’t have to be. We offer prompt claims settlement, so you can focus on recovery, not paperwork.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: What kind of coverage are we talking about?
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: Our comprehensive coverage includes everything: collision, theft, vandalism, natural disasters, and third-party liability. We also offer add-ons like zero depreciation, which ensures you get the full replacement value for parts in case of a claim.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Zero depreciation sounds essential. What about coverage for the battery? It's an EV, after all.
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: Excellent point! Our comprehensive plan specifically covers the battery and other electric vehicle components. Also with IFFCO Tokio, you’re choosing a provider known for its customer-first approach and streamlined claims resolution. Their policy ensures clarity and speed during stressful times like accidents or thefts.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: What's the premium for this level of coverage?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: For a 2018 Tesla Model 3 with comprehensive coverage, zero depreciation, and EV component protection, the annual premium would be around $3500. With features like cashless repair services, it streamlines the claim process, reducing administrative burdens and accelerating service delivery so vehicles can return to service faster.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: That sounds reasonable. What is the Insured Declared Value (IDV)?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: In the case of a total loss, this cover guarantees that the payout will match the original purchase price of the vehicle as per the invoice, rather than the depreciated current value, providing greater financial relief.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Great. How do I proceed with purchasing this policy?
# Selected Experts: ['keyterm expert', 'persuasion expert', 'sentiment expert']
# Agent: Excellent! I can email you a detailed policy document and a link to our secure online payment portal.  Or, if you prefer, we can schedule a call to walk through the details together. This is one of our most popular plans - most of our clients go for it because it offers complete peace of mind.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: I need to renew my car insurance. It's for a 2010 Honda Civic.
# Selected Experts: ['intent expert', 'keyterm expert']
# Agent: Okay, a 2010 Honda Civic. Are you primarily concerned with the lowest possible price, or are there specific coverages you're interested in?
# Selected Experts: ['intent expert', 'keyterm expert', 'sentiment expert']
# User: I'm on a fixed income, so price is definitely a factor. But I still need decent coverage.
# Selected Experts: ['intent expert', 'sentiment expert', 'persuasion expert']
# Agent: I understand. It’s important to protect yourself without breaking the bank. A third-party liability policy is the most affordable option, covering damages you might cause to others.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: What does that actually cover?
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: It covers damages to another person's vehicle or property if you're at fault in an accident. It doesn't cover damages to your own car.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Hmm, I see. How much would that cost?
# Selected Experts: ['keyterm expert', 'sentiment expert', 'persuasion expert']
# Agent: For a 2010 Honda Civic, a third-party liability policy would be approximately $800 per year. With Reliance General Insurance, its user-friendly claim process and focus on customer convenience work together to provide a smooth and reassuring experience during challenging times.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Is there anything else I should consider?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: Given your age and occasional driving, personal accident cover is worth considering. This rider provides additional financial support in case of serious injury or death resulting from a road accident, covering medical expenses, disability, or loss of income for the insured driver and eligible passengers.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: How much would that add to the premium?
# Selected Experts: ['persuasion expert', 'keyterm expert']
# Agent: Adding personal accident cover would increase the premium by about $50 per year. Since you’re budget-conscious and prefer simplicity, this policy offers essential protection at an affordable price point.
# Selected Experts: ['sentiment expert', 'intent expert']
# User: Okay, that doesn't sound too bad. What about discounts?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: Since you're renewing with us, you qualify for a loyalty discount. This discount rewards long-term customers with reduced premiums upon policy renewal, recognizing their loyalty and consistent risk profile over time.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Alright, that sounds good. Let's go with the third-party liability and the personal accident cover.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Hi, I'm interested in getting motor insurance for my bike. It's a 2022 Royal Enfield Interceptor 650.
# Selected Experts: ['intent expert', 'keyterm expert']
# Agent: Great choice! The Interceptor 650 is a fantastic bike. Do you use it for daily commuting or mostly for weekend rides?
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Mostly weekend rides. I like to take it out on the open road when I have time.
# Selected Experts: ['intent expert', 'persuasion expert']
# Agent: I understand. Given that you enjoy weekend rides, having comprehensive coverage will give you peace of mind on those long journeys. Imagine being stranded far from home due to a breakdown; our roadside assistance can be a lifesaver.
# Selected Experts: ['intent expert', 'keyterm expert', 'sentiment expert']
# User: Roadside assistance does sound good. What exactly does your comprehensive policy cover?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: It covers accidental damage, theft, natural disasters, and third-party liability. With IFFCO Tokio, you’re choosing a provider known for its customer-first approach and streamlined claims resolution. Their policy ensures clarity and speed during stressful times like accidents or thefts.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Okay, good to know. How much would a comprehensive policy cost me?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: For a 2022 Royal Enfield Interceptor 650, the comprehensive policy would be around $850 per year. Also as you're a professional and use your bike only for occasional drives, we can offer a discount.
# Selected Experts: ['sentiment expert', 'keyterm expert']
# User: That sounds reasonable. Does it include zero depreciation?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: We can add a zero depreciation cover for an additional $100 per year. This ensures that in the event of a claim, the repair or replacement costs are calculated based on the current market value of new parts, rather than depreciated values, offering maximum reimbursement.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Okay, that's good to know. I'm interested. Can you send me a quote with and without the zero depreciation cover?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: Absolutely! I'll email you both quotes right away. Many of our clients opt for the zero depreciation cover, as it can save you a lot of money in the long run.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Hi, I'm looking to get insurance for my bike. It's a 2022 Yamaha MT-07.
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: Great choice, the MT-07 is a fantastic bike! Since you're a daily commuter, have you considered a comprehensive plan that covers everything from accidents to theft?
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Yeah, I was thinking comprehensive would be best. I commute in heavy traffic, so I want to be covered. What are my options?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: Accidents are unpredictable, but the financial stress doesn’t have to be. Bajaj Allianz offers prompt claims settlement, so you can focus on getting back on the road, not paperwork.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Okay, good to know. What kind of coverage levels are we talking about?
# Selected Experts: ['keyterm expert', 'persuasion expert', 'sentiment expert']
# Agent: We can tailor the coverage to your needs. For example, a comprehensive policy with IFFCO Tokio covers key risks such as accidents and theft. It simplifies the claims process through a well-organized system that focuses on customer ease and timely resolution, ensuring clarity and efficiency throughout the insurance experience.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: That sounds pretty good. What about add-ons? Are there any I should consider?
# Selected Experts: ['intent expert', 'persuasion expert', 'keyterm expert']
# Agent: Since you commute daily, Roadside Assistance is invaluable. This service ensures that help is available at any time if you experience vehicle breakdowns, requiring towing services, tire changes, fuel delivery, or emergency repairs while on the road.
# Selected Experts: ['intent expert', 'keyterm expert', 'sentiment expert']
# User: Roadside assistance does sound useful. Okay, what's the damage? How much would all of this cost?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: For a 2022 Yamaha MT-07 with comprehensive coverage and roadside assistance, you're looking at around $950 annually. This is one of our most popular plans—most of our clients go for it because it’s affordable and offers complete peace of mind for daily drivers
# Selected Experts: ['intent expert', 'keyterm expert']
# User: That sounds reasonable. Can you send me a quote with all the details?
# Selected Experts: ['keyterm expert', 'intent expert', 'persuasion expert']
# Agent: Absolutely! I'll email you a detailed quote right away. It will outline all the coverage and benefits. Since you prefer self-service options, Tata AIG’s policy with Online Policy Management suits your tech-savvy lifestyle.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Hi, I'm looking to get insurance for my bike. It's a 2022 Yamaha MT-07.
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: Great choice! The Yamaha MT-07 is a fantastic bike. Since you're a professional and likely use your bike for daily commuting, let's explore options that offer robust protection and convenience.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Yes, I use it every day for my commute. What kind of coverage do you recommend?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: Given your daily commute, a comprehensive policy with roadside assistance is highly recommended. You never know when you might face a breakdown or flat tire, especially during rush hour.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Roadside assistance sounds useful. What else does the comprehensive policy cover?
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: It covers accidental damage, theft, and third-party liability. Imagine someone were to damage your bike while it's parked; our policy would cover the repair costs.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Okay, that sounds good. Which company do you recommend?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: I would recommend Bajaj Allianz. They are known for their quick claim settlements and reliable customer service. Choosing Bajaj Allianz offers you peace of mind during stressful times.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: And what's the premium for the comprehensive policy with Bajaj Allianz?
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: For your 2022 Yamaha MT-07, the annual premium would be approximately $1200. This includes comprehensive coverage and roadside assistance.
# Selected Experts: ['intent expert', 'keyterm expert', 'sentiment expert']
# User: That sounds pretty reasonable. I am interested in the policy. Can I get additional discount on it?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: Yes, since you commute everyday, we can offer you a discount under the commuter discount policy. And with Bajaj Allianz, you’re choosing a provider known for its customer-first approach and streamlined claims resolution.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Sure, that sounds great. Please provide me with the discount.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Hi, I am looking for a motor insurance policy for my bike. It's a 2022 Royal Enfield Classic 350.
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: Okay, great! The Royal Enfield Classic 350 is a fantastic bike. Since you are a daily commuter, comprehensive coverage is usually a good option. It covers not just third-party liabilities, but also damages to your bike.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: What all is covered in a comprehensive policy?
# Selected Experts: ['keyterm expert', 'sentiment expert']
# Agent: A comprehensive policy typically includes coverage for accidents, theft, natural disasters, fire, and vandalism. With Bajaj Allianz, we also ensure that claims are settled quickly. With Bajaj Allianz, you can focus on recovery, not paperwork.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: That sounds good. What would be the premium for a comprehensive policy?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: For a 2022 Royal Enfield Classic 350, a comprehensive policy would be around $950 annually. Because you are a daily commuter and value financial security, we believe that this policy suits you best.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Are there any add-ons available with this policy?
# Selected Experts: ['keyterm expert', 'intent expert']
# Agent: Yes, we have several add-ons like Zero Depreciation Cover and Roadside Assistance. As a daily rider, Roadside Assistance could be particularly useful in case of a breakdown.
# Selected Experts: ['keyterm expert']
# User: What is Zero Depreciation Cover?
# Selected Experts: ['keyterm expert', 'sentiment expert']
# Agent: Zero Depreciation Cover ensures that in the event of a claim, the repair or replacement costs are calculated based on the current market value of new parts, rather than depreciated values, offering maximum reimbursement. Accidents are unpredictable, and you can be financially prepared by taking this add-on.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: Okay, that makes sense. How much would the policy cost with Zero Depreciation and Roadside Assistance?
# Selected Experts: ['keyterm expert', 'sentiment expert', 'persuasion expert']
# Agent: With those add-ons, the premium would be approximately $1200 per year. Our policy ensures clarity and speed during stressful times like accidents or thefts. It’s a good choice if you are looking for complete peace of mind.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: That sounds like a good deal. Can you send me more details about the policy?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: Certainly! I will email you a detailed brochure with all the coverage details and terms and conditions. This is one of our most popular plans—most of our clients go for it because it offers complete peace of mind for daily drivers.
# Selected Experts: ['sentiment expert', 'intent expert']
# User: Thank you. I look forward to receiving it.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: I need to insure my 2024 Tesla Model 3. What are my options?
# Selected Experts: ['sentiment expert', 'persuasion expert']
# Agent: The Tesla Model 3 is an excellent vehicle. As a business owner, you likely appreciate efficiency and reliability. HDFC ERGO General Insurance focuses on delivering prompt assistance and support around the clock, ensuring that any claims or inquiries are handled efficiently at any time.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: What kind of coverage do you recommend?
# Selected Experts: ['intent expert', 'persuasion expert', 'keyterm expert']
# Agent: Given that it’s a new and valuable car, I strongly recommend a comprehensive policy that includes Zero Depreciation cover and Insured Declared Value (IDV).
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Why is IDV important?
# Selected Experts: ['keyterm expert', 'intent expert', 'sentiment expert']
# Agent: IDV ensures you receive the original invoice value in the event of a total loss. In the case of a total loss, this cover guarantees that the payout will match the original purchase price of the vehicle as per the invoice, rather than the depreciated current value, providing greater financial relief.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: And what about coverage for the battery? It’s an electric car.
# Selected Experts: ['keyterm expert', 'sentiment expert', 'persuasion expert']
# Agent: Our comprehensive policy covers the battery against damage from accidents, fire, and certain types of malfunctions. Think of it as an investment in your safety and security. Accidents happen, and the cost of repairs can be significant.
# Selected Experts: ['keyterm expert', 'intent expert']
# User: How much will all this cost?
# Selected Experts: ['intent expert', 'keyterm expert', 'persuasion expert']
# Agent: For a 2024 Tesla Model 3 with comprehensive coverage, Zero Depreciation, and IDV, the annual premium would be around $4200. Because you are a business owner and prioritize complete peace of mind, we can customize this policy to best suit you.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: That's a bit expensive. Are there any discounts available?
# Selected Experts: ['keyterm expert', 'persuasion expert']
# Agent: Yes, we offer a digital purchase discount if you buy the policy online. Also, since you may not be driving as much, we can look at usage-based insurance to bring down the premium a bit, which rewards you for safe driving habits.
# Selected Experts: ['intent expert', 'keyterm expert']
# User: Okay, that sounds interesting. Tell me more about the usage-based insurance.

# %%
import json
import re

# Function to clean markdown and formatting from text
def clean_text(text):
    # Remove markdown symbols and line breaks
    cleaned = re.sub(r'[*`_>#\\\-\r\n]+', ' ', text)
    cleaned = re.sub(r'\s+', ' ', cleaned)  # Collapse multiple spaces into one
    return cleaned.strip()

# Input and output file paths
input_file = "/home/rohank__iitp/Work/niladri/dataset2/router/router_response.jsonl"   # Replace with your actual input filename
output_file = "/home/rohank__iitp/Work/niladri/dataset2/router/cleaned_output.jsonl"

# Process each line
with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
    for line in infile:
        data = json.loads(line)
        data["answer"] = clean_text(data["answer"])
        outfile.write(json.dumps(data) + "\n")

print(f"Cleaned data written to {output_file}")
# Out:
# Cleaned data written to /home/rohank__iitp/Work/niladri/dataset2/router/cleaned_output.jsonl
